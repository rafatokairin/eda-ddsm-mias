# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plot
import numpy as np # álgebra linear
import os # acesso ao diretório
import pandas as pd # processamento dos dados .csv
import math
from starter_pack.func_analysis import plotPerColumnDistribution, plotCorrelationMatrix, plotScatterMatrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 import pandas as pd # processamento dos dados .csv
#       7 import math
# ----> 8 from starter_pack.func_analysis import plotPerColumnDistribution, plotCorrelationMatrix, plotScatterMatrix
#
# ModuleNotFoundError: No module named 'starter_pack'

# %% [markdown]
# ### Vamos verificar 4st arquivo: /kaggle/input/csv/dicom_info.csv

# %%
nRowsRead = 1000 # especifique 'None' se quiser ler o arquivo inteiro
# dicom_info.csv pode ter mais linhas na realidade, mas estamos carregando/visualizando apenas as primeiras 1000 linhas
df4 = pd.read_csv('/home/rafatokairin/uni-programs/ic/csv/dicom_info.csv', delimiter=',', nrows = nRowsRead)
df4.dataframeName = 'dicom_info.csv'
nRow, nCol = df4.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 38 columns

# %% [markdown]
# Vamos dar uma olhada rápida em como os dados se apresentam:

# %%
df4.head(5)
# Out:
#                                            file_path  \
# 0  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.12930...
# 1  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.24838...
# 2  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.26721...
# 3  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
# 4  CBIS-DDSM/dicom/1.3.6.1.4.1.9590.100.1.2.38118...
#
#                                           image_path  AccessionNumber  \
# 0  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.129308...              NaN
# 1  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.248386...              NaN
# 2  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.267213...              NaN
# 3  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
# 4  CBIS-DDSM/jpeg/1.3.6.1.4.1.9590.100.1.2.381187...              NaN
#
#    BitsAllocated  BitsStored BodyPartExamined  Columns  ContentDate  \
# 0             16          16           BREAST      351     20160426
# 1             16          16           BREAST     3526     20160426
# 2             16          16           BREAST     1546     20160503
# 3             16          16           BREAST       97     20160503
# 4              8           8      Left Breast     3104     20160503
#
#    ContentTime ConversionType  ...  \
# 0   131732.685            WSD  ...
# 1   143829.101            WSD  ...
# 2   111956.298            WSD  ...
# 3   115347.770            WSD  ...
# 4   115347.770            WSD  ...
#
#    SecondaryCaptureDeviceManufacturerModelName      SeriesDescription  \
# 0                                       MATLAB         cropped images
# 1                                       MATLAB  full mammogram images
# 2                                       MATLAB  full mammogram images
# 3                                       MATLAB         cropped images
# 4                                       MATLAB                    NaN
#
#                                    SeriesInstanceUID SeriesNumber  \
# 0  1.3.6.1.4.1.9590.100.1.2.129308726812851964007...            1
# 1  1.3.6.1.4.1.9590.100.1.2.248386742010678582309...            1
# 2  1.3.6.1.4.1.9590.100.1.2.267213171011171858918...            1
# 3  1.3.6.1.4.1.9590.100.1.2.381187369611524586537...            1
# 4  1.3.6.1.4.1.9590.100.1.2.381187369611524586537...            1
#
#   SmallestImagePixelValue  SpecificCharacterSet   StudyDate StudyID  \
# 0                   23078            ISO_IR 100  20160720.0    DDSM
# 1                       0            ISO_IR 100  20160720.0    DDSM
# 2                       0            ISO_IR 100  20160807.0    DDSM
# 3                   32298            ISO_IR 100  20170829.0    DDSM
# 4                       0            ISO_IR 100         NaN    DDSM
#
#                                     StudyInstanceUID  StudyTime
# 0  1.3.6.1.4.1.9590.100.1.2.271867287611061855725...   214951.0
# 1  1.3.6.1.4.1.9590.100.1.2.161516517311681906612...   193426.0
# 2  1.3.6.1.4.1.9590.100.1.2.291043622711253836701...   161814.0
# 3  1.3.6.1.4.1.9590.100.1.2.335006093711888937440...   180109.0
# 4  1.3.6.1.4.1.9590.100.1.2.335006093711888937440...        NaN
#
# [5 rows x 38 columns]

# %%
# dimensões do arquivo
df4.shape
# Out:
# (1000, 38)

# %%
# informações do arquivo
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 38 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   file_path                                    1000 non-null   object
#  1   image_path                                   1000 non-null   object
#  2   AccessionNumber                              0 non-null      float64
#  3   BitsAllocated                                1000 non-null   int64
#  4   BitsStored                                   1000 non-null   int64
#  5   BodyPartExamined                             1000 non-null   object
#  6   Columns                                      1000 non-null   int64
#  7   ContentDate                                  1000 non-null   int64
#  8   ContentTime                                  1000 non-null   float64
#  9   ConversionType                               1000 non-null   object
#  10  HighBit                                      1000 non-null   int64
#  11  InstanceNumber                               1000 non-null   int64
#  12  LargestImagePixelValue                       1000 non-null   int64
#  13  Laterality                                   934 non-null    object
#  14  Modality                                     1000 non-null   object
#  15  PatientBirthDate                             0 non-null      float64
#  16  PatientID                                    1000 non-null   object
#  17  PatientName                                  1000 non-null   object
#  18  PatientOrientation                           1000 non-null   object
#  19  PatientSex                                   0 non-null      float64
#  20  PhotometricInterpretation                    1000 non-null   object
#  21  PixelRepresentation                          1000 non-null   int64
#  22  ReferringPhysicianName                       0 non-null      float64
#  23  Rows                                         1000 non-null   int64
#  24  SOPClassUID                                  1000 non-null   object
#  25  SOPInstanceUID                               1000 non-null   object
#  26  SamplesPerPixel                              1000 non-null   int64
#  27  SecondaryCaptureDeviceManufacturer           1000 non-null   object
#  28  SecondaryCaptureDeviceManufacturerModelName  1000 non-null   object
#  29  SeriesDescription                            934 non-null    object
#  30  SeriesInstanceUID                            1000 non-null   object
#  31  SeriesNumber                                 1000 non-null   int64
#  32  SmallestImagePixelValue                      1000 non-null   int64
#  33  SpecificCharacterSet                         1000 non-null   object
#  34  StudyDate                                    934 non-null    float64
#  35  StudyID                                      1000 non-null   object
#  36  StudyInstanceUID                             1000 non-null   object
#  37  StudyTime                                    934 non-null    float64
# dtypes: float64(7), int64(12), object(19)
# memory usage: 297.0+ KB

# %%
df4.isnull().sum()
# Out:
# file_path                                         0
# image_path                                        0
# AccessionNumber                                1000
# BitsAllocated                                     0
# BitsStored                                        0
# BodyPartExamined                                  0
# Columns                                           0
# ContentDate                                       0
# ContentTime                                       0
# ConversionType                                    0
# HighBit                                           0
# InstanceNumber                                    0
# LargestImagePixelValue                            0
# Laterality                                       66
# Modality                                          0
# PatientBirthDate                               1000
# PatientID                                         0
# PatientName                                       0
# PatientOrientation                                0
# PatientSex                                     1000
# PhotometricInterpretation                         0
# PixelRepresentation                               0
# ReferringPhysicianName                         1000
# Rows                                              0
# SOPClassUID                                       0
# SOPInstanceUID                                    0
# SamplesPerPixel                                   0
# SecondaryCaptureDeviceManufacturer                0
# SecondaryCaptureDeviceManufacturerModelName       0
# SeriesDescription                                66
# SeriesInstanceUID                                 0
# SeriesNumber                                      0
# SmallestImagePixelValue                           0
# SpecificCharacterSet                              0
# StudyDate                                        66
# StudyID                                           0
# StudyInstanceUID                                  0
# StudyTime                                        66
# dtype: int64

# %% [markdown]
# Verificar os valores únicos em cada coluna

# %%
valores_unicos = []
for i in df4.columns[0:39].tolist():
    print(i, ':', len(df4[i].astype(str).value_counts()))
    valores_unicos.append(len(df4[i].astype(str).value_counts()))
# Out:
# file_path : 1000
# image_path : 1000
# AccessionNumber : 1
# BitsAllocated : 2
# BitsStored : 2
# BodyPartExamined : 3
# Columns : 517
# ContentDate : 4
# ContentTime : 671
# ConversionType : 1
# HighBit : 2
# InstanceNumber : 1
# LargestImagePixelValue : 43
# Laterality : 3
# Modality : 1
# PatientBirthDate : 1
# PatientID : 712
# PatientName : 699
# PatientOrientation : 2
# PatientSex : 1
# PhotometricInterpretation : 1
# PixelRepresentation : 1
# ReferringPhysicianName : 1
# Rows : 436
# SOPClassUID : 1
# SOPInstanceUID : 1000
# SamplesPerPixel : 1
# SecondaryCaptureDeviceManufacturer : 2
# SecondaryCaptureDeviceManufacturerModelName : 1
# SeriesDescription : 4
# SeriesInstanceUID : 671
# SeriesNumber : 1
# SmallestImagePixelValue : 295
# SpecificCharacterSet : 1
# StudyDate : 9
# StudyID : 1
# StudyInstanceUID : 671
# StudyTime : 854

# %%
df4.describe()
# Out:
#        AccessionNumber  BitsAllocated  BitsStored      Columns   ContentDate  \
# count              0.0     1000.00000  1000.00000  1000.000000  1.000000e+03
# mean               NaN       13.23200    13.23200  2175.046000  2.016047e+07
# std                NaN        3.80745     3.80745  1335.257997  4.210159e+01
# min                NaN        8.00000     8.00000    77.000000  2.016041e+07
# 25%                NaN        8.00000     8.00000   503.750000  2.016043e+07
# 50%                NaN       16.00000    16.00000  2716.000000  2.016050e+07
# 75%                NaN       16.00000    16.00000  3091.750000  2.016050e+07
# max                NaN       16.00000    16.00000  5071.000000  2.016060e+07
#
#          ContentTime     HighBit  InstanceNumber  LargestImagePixelValue  \
# count    1000.000000  1000.00000          1000.0             1000.000000
# mean   122971.969388    12.23200             1.0            42715.271000
# std     12097.878703     3.80745             0.0            30923.117977
# min     82759.495003     7.00000             1.0              255.000000
# 25%    113244.775750     7.00000             1.0              255.000000
# 50%    122748.122000    15.00000             1.0            65535.000000
# 75%    132054.169000    15.00000             1.0            65535.000000
# max    160501.169000    15.00000             1.0            65535.000000
#
#        PatientBirthDate  PatientSex  PixelRepresentation  \
# count               0.0         0.0               1000.0
# mean                NaN         NaN                  0.0
# std                 NaN         NaN                  0.0
# min                 NaN         NaN                  0.0
# 25%                 NaN         NaN                  0.0
# 50%                 NaN         NaN                  0.0
# 75%                 NaN         NaN                  0.0
# max                 NaN         NaN                  0.0
#
#        ReferringPhysicianName         Rows  SamplesPerPixel  SeriesNumber  \
# count                     0.0  1000.000000           1000.0        1000.0
# mean                      NaN  3591.826000              1.0           1.0
# std                       NaN  2333.821357              0.0           0.0
# min                       NaN    81.000000              1.0           1.0
# 25%                       NaN   487.000000              1.0           1.0
# 50%                       NaN  4640.000000              1.0           1.0
# 75%                       NaN  5446.000000              1.0           1.0
# max                       NaN  6916.000000              1.0           1.0
#
#        SmallestImagePixelValue     StudyDate      StudyTime
# count              1000.000000  9.340000e+02     934.000000
# mean               8674.103000  2.016441e+07  157940.194861
# std               14824.187881  4.832690e+03   50687.650739
# min                   0.000000  2.016072e+07   82241.000000
# 25%                   0.000000  2.016072e+07   90838.500000
# 50%                   0.000000  2.016081e+07  170942.500000
# 75%               17020.750000  2.017083e+07  214736.000000
# max               57821.000000  2.017093e+07  215547.000000

# %% [markdown]
# Gráficos de distribuição (histograma/gráfico de barras) das colunas amostradas:

# %%
plotPerColumnDistribution(df4, 11, 5)

# %% [markdown]
# Matriz de correlação:

# %%
plotCorrelationMatrix(df4, 8)

# %% [markdown]
# Gráficos de dispersão e densidade:

# %%
plotScatterMatrix(df4, 15, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plotScatterDensity(df4, 15, 10)
#
# TypeError: plotScatterDensity() takes from 1 to 2 positional arguments but 3 were given
